# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
PCE = pd.read_csv('rf_desc_with_predictions.csv')
PCE
# Out:
#      Unnamed: 0  Unnamed: 0.1    acceptor    donor                 reference  \
# 0           975           975          Y6  PBDB-TF          Meng_18.77%_2021
# 1           974           974          Y6      D18              Jin_D18_2021
# 2           932           932          Y5  PBDB-TF  Cui_single-junction_2020
# 3           709           709  m-BTP-PhC6    PTQ10      Fan_synergistic_2021
# 4           160           160     BTP-4Cl  PBDB-TF            Ma_impact_2021
# ..          ...           ...         ...      ...                       ...
# 498         987           987     YITI-2F   PBDB-T           Yue_design_2018
# 499         410           410  IDTT2OT-2F   PBDB-T        Kim_synthesis_2021
# 500         455           455   IFIC-i-4F  PTB7-Th        Liu_achieving_2019
# 501         314           314      i-cc34   PBDB-T       Luo_side-chain_2017
# 502         205           205      CPIC-2   PBDB-T   Yuan_near-infrared_2021
#
# ...

# %%
sns.scatterplot(data = PCE, x="predicted_PCE", y="PCE", hue="acceptor class", palette="Dark2")
plt.savefig('acceptor_class_predictions.png')
