# %% [markdown]
# # Quick check of fragements to make sure there are no radical electrons or bonding mistakes

# %%
import glob
from rdkit.Chem import Descriptors
from rdkit import Chem

# %%
for filename in glob.iglob('*.smi'):
    with open(filename, 'r', encoding = 'utf-8') as file:
        smiles = file.readline()
    
    print(filename)
    mol = Chem.MolFromSmiles(smiles)

    if Descriptors.NumRadicalElectrons(mol) > 0:
        print(file)
# Out:
# 0_TL.smi
# 0_TR.smi
# 100_C.smi
# 101_C.smi
# 102_C.smi
# 103_C.smi
# 104_TL.smi
# 104_TR.smi
# 105_C.smi
# 106_TL.smi
# 106_TR.smi
# 107_TL.smi
# 107_TR.smi
# 108_C.smi
# 109_TL.smi
# 109_TR.smi
# 10_TL.smi
# 10_TR.smi
# 110_C.smi
# 111_TL.smi
# 111_TR.smi
# 112_C.smi
# 113_C.smi
# 114_C.smi
# 115_C.smi
# 116.smi
# 116_C.smi
# 117_C.smi
# 118_C.smi
# 119_C.smi
# 11_C.smi
# 120_C.smi
# 121_C.smi
# 122_C.smi
# 123_C.smi
# 124_C.smi
# 125_C.smi
# 126_C.smi
# 128_C.smi
# 129_C.smi
# 12_TL.smi
# 12_TR.smi
# 130_C.smi
# 131_C.smi
# 132_C.smi
# 133_C.smi
# 134_C.smi
# 135_C.smi
# 136_C.smi
# 137_C.smi
# 138_C.smi
# 139_C.smi
# 13_C.smi
# 140_C.smi
# 141_C.smi
# 143_C.smi
# 144_C.smi
# 145_C.smi
# 146_C.smi
# 147_C.smi
# 148_C.smi
# 149_C.smi
# 14_C.smi
# 150_C.smi
# 151_TL.smi
# 151_TR.smi
# 152_C.smi
# 153_C.smi
# 154_TL.smi
# 154_TR.smi
# 155_C.smi
# 156_C.smi
# 157_C.smi
# 158_C.smi
# 159_TL.smi
# 159_TR.smi
# 15_C.smi
# 160_C.smi
# 161_TL.smi
# 161_TR.smi
# 162_TL.smi
# 162_TR.smi
# 164_C.smi
# 165_C.smi
# 166_C.smi
# 167_TL.smi
# 167_TR.smi
# 168_C.smi
# 169_C.smi
# 16_C.smi
# 170_TL.smi
# 170_TR.smi
# 172_TL.smi
# 172_TR.smi
# 173_C.smi
# 174_C.smi
# 176_C.smi
# 177_C.smi
# 178_C.smi
# 179_C.smi
# 17_C.smi
# 180_C.smi
# 181_C.smi
# 182_C.smi
# 183_C.smi
# 184_C.smi
# 185_C.smi
# 186_C.smi
# 187_C.smi
# 188_C.smi
# 189_C.smi
# 18_C.smi
# 190_C.smi
# 191_C.smi
# 192_C.smi
# 193_C.smi
# 194_TL.smi
# 194_TR.smi
# 195_C.smi
# 196_C.smi
# 197_C.smi
# 198_C.smi
# 199_C.smi
# 19_C.smi
# 1_TL.smi
# 1_TR.smi
# 200_C.smi
# 201_C.smi
# 202_C.smi
# 203_C.smi
# 204_C.smi
# 205_C.smi
# 206_C.smi
# 207_C.smi
# 208_TL.smi
# 208_TR.smi
# 20_C.smi
# 210_C.smi
# 211_TL.smi
# 211_TR.smi
# 212_TL.smi
# 212_TR.smi
# 213_TL.smi
# 213_TR.smi
# 214_C.smi
# 215_C.smi
# 216_C.smi
# 217_C.smi
# 219_C.smi
# 21_C.smi
# 220_C.smi
# 221_C.smi
# 222_TL.smi
# 222_TR.smi
# 223_TL.smi
# 223_TR.smi
# 224_C.smi
# 225_C.smi
# 226_TL.smi
# 226_TR.smi
# 227_C.smi
# 228_C.smi
# 229_C.smi
# 22_C.smi
# 230_C.smi
# 231_TL.smi
# 231_TR.smi
# 232_TL.smi
# 232_TR.smi
# 233_C.smi
# 234_TL.smi
# 234_TR.smi
# 235_TL.smi
# 235_TR.smi
# 236_C.smi
# 237_C.smi
# 238_C.smi
# 239_C.smi
# 240_C.smi
# 241_C.smi
# 242_C.smi
# 243_C.smi
# 244_C.smi
# 245_C.smi
# 246_C.smi
# 247_C.smi
# 248_C.smi
# 249_C.smi
# 250_C.smi
# 251_C.smi
# 252_C.smi
# 253_C.smi
# 254_C.smi
# 255_C.smi
# 256_C.smi
# 257_C.smi
# 258_C.smi
# 261_C.smi
# 262_C.smi
# 263_C.smi
# 264_C.smi
# 265_C.smi
# 266_C.smi
# 267_C.smi
# 268_C.smi
# 269_TL.smi
# 269_TR.smi
# 26_C.smi
# 270_C.smi
# 271_C.smi
# 273_C.smi
# 274_TL.smi
# 274_TR.smi
# 275_TL.smi
# 275_TR.smi
# 276_C.smi
# 277_C.smi
# 278_C.smi
# 279_C.smi
# 27_TL.smi
# 27_TR.smi
# 280_C.smi
# 281_C.smi
# 282_C.smi
# 283_C.smi
# 284_C.smi
# 285_C.smi
# 286_C.smi
# 287_C.smi
# 288_C.smi
# 289_C.smi
# 28_TL.smi
# 28_TR.smi
# 290_C.smi
# 291_C.smi
# 292_C.smi
# 293_C.smi
# 294_C.smi
# 295_C.smi
# 296_C.smi
# 298_C.smi
# 299_C.smi
# 29_C.smi
# 2_C.smi
# 300_C.smi
# 301_C.smi
# 302_C.smi
# 303_C.smi
# 304_C.smi
# 305_C.smi
# 306_TL.smi
# 306_TR.smi
# 307_C.smi
# 308_C.smi
# 309_C.smi
# 30_C.smi
# 310_TL.smi
# 310_TR.smi
# 311_C.smi
# 312_TL.smi
# 312_TR.smi
# 313_TL.smi
# 313_TR.smi
# 314_TL.smi
# 314_TR.smi
# 315_C.smi
# 316_C.smi
# 317_TL.smi
# 317_TR.smi
# 318_C.smi
# 319_C.smi
# 31_TL.smi
# 31_TR.smi
# 320_C.smi
# 321_C.smi
# 322_C.smi
# 323_C.smi
# 324_C.smi
# 325_C.smi
# 326_C.smi
# 327_C.smi
# 328_C.smi
# 329_C.smi
# 32_C.smi
# 330_C.smi
# 331_C.smi
# 332_C.smi
# 335_C.smi
# 336_C.smi
# 337_C.smi
# 338_C.smi
# 339_C.smi
# 33_C.smi
# 341_C.smi
# 342_C.smi
# 343_C.smi
# 345_C.smi
# 346_C.smi
# 347_C.smi
# 348_C.smi
# 349_C.smi
# 34_C.smi
# 350_C.smi
# 351_C.smi
# 354_C.smi
# 355_C.smi
# 356_C.smi
# 357_C.smi
# 358_C.smi
# 359_C.smi
# 35_C.smi
# 360_TL.smi
# 360_TR.smi
# 361_TL.smi
# 361_TR.smi
# 363_C.smi
# 364_C.smi
# 365_C.smi
# 366_C.smi
# 367_C.smi
# 368_C.smi
# 369_C.smi
# 36_C.smi
# 370_C.smi
# 371_C.smi
# 372_C.smi
# 373_C.smi
# 374_C.smi
# 375_C.smi
# 376_C.smi
# 377_C.smi
# 378_C.smi
# 379_C.smi
# 37_TL.smi
# 37_TR.smi
# 380_C.smi
# 381_C.smi
# 382_C.smi
# 383_C.smi
# 385_C.smi
# 386_C.smi
# 387_C.smi
# 388_C.smi
# 389_C.smi
# 38_C.smi
# 390_C.smi
# 391_C.smi
# 393_C.smi
# 394_C.smi
# 395_C.smi
# 396_C.smi
# 397_C.smi
# 398_C.smi
# 399_C.smi
# 39_C.smi
# 3_C.smi
# 400_C.smi
# 401_C.smi
# 402_TL.smi
# 402_TR.smi
# 40_TL.smi
# 40_TR.smi
# 41_C.smi
# 42_TL.smi
# 42_TR.smi
# 43_TL.smi
# 43_TR.smi
# 44_C.smi
# <_io.TextIOWrapper name='44_C.smi' mode='r' encoding='utf-8'>
# 45_C.smi
# 46_C.smi
# 47_C.smi
# 48_TL.smi
# 48_TR.smi
# 49_C.smi
# 4_C.smi
# 52_C.smi
# 53_C.smi
# 54_C.smi
# 55_C.smi
# 56_C.smi
# 57_C.smi
# 58_TL.smi
# 58_TR.smi
# 59_TL.smi
# 59_TR.smi
# 5_C.smi
# 60_C.smi
# 61_C.smi
# 62_TL.smi
# 62_TR.smi
# 63_TL.smi
# 63_TR.smi
# 64_TL.smi
# 64_TR.smi
# 65_C.smi
# 66_TL.smi
# 66_TR.smi
# 67_C.smi
# 68_TL.smi
# 68_TR.smi
# 69_C.smi
# 6_C.smi
# 70_C.smi
# 71_C.smi
# 72_TL.smi
# 72_TR.smi
# 73_TL.smi
# 73_TR.smi
# 74_TL.smi
# 74_TR.smi
# 75_TL.smi
# 75_TR.smi
# 76_C.smi
# 77_TL.smi
# 77_TR.smi
# 78_C.smi
# 79_C.smi
# 7_C.smi
# 80_C.smi
# 81_C.smi
# 82_C.smi
# 83_TL.smi
# 83_TR.smi
# 84_TL.smi
# 84_TR.smi
# 85_TL.smi
# 85_TR.smi
# 86_TL.smi
# 86_TR.smi
# 87_C.smi
# 88_TL.smi
# 88_TR.smi
# 89_TL.smi
# 89_TR.smi
# 8_C.smi
# 90_C.smi
# 91_C.smi
# 92_C.smi
# 93_C.smi
# 94_C.smi
# 95_C.smi
# 96_C.smi
# 97_TL.smi
# 97_TR.smi
# 98_TL.smi
# 98_TR.smi
# 99_C.smi
# 9_C.smi
